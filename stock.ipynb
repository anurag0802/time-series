# %% [markdown]
# #load the data

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\lenovo\appdata\roaming\python\python314\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from statsmodels) (2.3.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# %%
data=yf.download("AAPL",start="2015-01-01",end="2024-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df=data[['Close']]
df.dropna(inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16376\216802012.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
#ada test

res=adfuller(df['Close'])
res
# Out:
# (np.float64(0.2437935641630765),
#  np.float64(0.974613608705261),
#  18,
#  2245,
#  {'1%': np.float64(-3.4332661660670696),
#   '5%': np.float64(-2.8628282823666926),
#   '10%': np.float64(-2.567455813463227)},
#  np.float64(8941.878908672701))

# %%
#making stationary
df['diff_close']=df['Close'].diff().dropna(inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_16376\3113301192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diff_close']=df['Close'].diff().dropna(inplace=True)
